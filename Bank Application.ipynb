# %%
Account_detail={
    'A101':{'password':'Sachin','name':'Sachin','Mobileno':9511339055,'Address':'Jaipur','balance':200,'account_type':'S'}
}

while True:
    n=int(input('''
    Press 1 for Signup 
    Press 2 for Login 
    Press 3 for Forget Password 
    Press 4 for Exit
    '''))
    if n==1:
        print('*'*10,'Welcome to Besahara Bank🐫🐫','*'*10)
        while True:

            n=int(input('''
               Press 1 for Create Acoount
               Press 2 for Exit
            '''))
            if n==1:
                print('Welcome to the Account Handling Department')
                print('We Would like to request you with some detail')
                name=input('Enter Your name')
                no=int(input('Enter your mobile no'))
                address=input('Enter your address')
                account_type=input('''
                Press "S" for Saving Account
                Press "C" for Current Account 
                ''')
                a=list(Account_detail.keys())[-1]
                account_no=a[0]+str(int(a[1:])+1)
                while True:
                    password=input('Enter a Strong Password')
                    b = "qwertyuiopasdfghjklzxcvbnm"
                    d = {
                    "cap" : b.upper(),
                    "low" : b,
                    "num" : '0123456789',
                    "sc"  : '!@#$%^&*()-=+_<>?/.,;:' 
                    }
                    c,l,s,n = 0,0,0,0
                    for i in password:
                        if i in d['cap']:
                            c += 1
                        elif i in d['low']:
                            l += 1
                        elif i in d['sc']:
                            s += 1
                        elif i in d['num']:
                            n += 1

                    ls = []
                    if c == 0:
                        ls.append("Capital letters")
                    if l == 0:
                        ls.append("Small Letters")
                    if s == 0:
                        ls.append("Special Characters")
                    if n == 0:
                        ls.append("Numbers")

                    if len(ls) == 0 and len(password) > 7:
                        break
                    else:
                        print("Your password is Weak")
                        if len(password) < 7:
                            print("Your password must have at least 8 characters")
                        if ls != 0:
                            print(ls,"are missing in your password ")
                while True:
                    balance=int(input('Enter Intial Balance To depoist must be greater than 2000'))
                    if balance>=2000:
                        break
                    else:
                        print('Deposited Balance is less than 2000')
                    

                d[account_no]={'password':password,'name':name.title(),'Mobileno':no,'Adress':address,'Balance':balance,'account_type':account_type.upper()}
                print(f'''
                Welcome {name}

                            Your Account no : {account_no}
                            Your Password   : {password}
                            ''')
                break
            elif n==2:
                break
            else:
                print('Invalid Input')
    elif n==2:
        i=0
        while True: 
            username=input('Enter your username')
            password=input('Enter Your Password')
            i+=1
            if username.upper() in list(Account_detail.keys()):
                if password ==Account_detail[username.upper()]['password']:
                    print('Login Successfully')
                    break
                else:
                    print('Wrong Password')
            else :
                print('No username Found')
            if i>=3:
                sys.exit('You have entered 3 wrong password in a row')
        while True:
            k=int(input('''
                Press 1 for Credit 
                Press 2 for Debit
                Press 3 for Change Password 
                Press 4 for Check Balance
                Press 5 for Show Details
                Press 6 for Logout
            '''))
            if k==1:
                credit_amount=int(input('Enter Amount to Deposit'))
                Account_detail[username.upper()]['balance']+=credit_amount
            elif k==2:
                debit_amount=int(input('Enter Amount to debit'))
                if debit_amount>Account_detail[username.upper()]['balance']:
                    print('Aukad se bahar😎😎')
                else:
                    Account_detail[username.upper()]['balance']-=debit_amount
                    print(f'''

                    Amount Debited-->{debit_amount}
                    Present Balance-->{Account_detail[username.upper()]['balance']}

                    Kya karega itne paise ka 😏😏

                    ''')
                if Account_detail[username.upper()]['balance']<2000:
                    print('Paisa kam hai tere paas 😆😅')

            elif k==3:
                while True:
                    password=input('Enter your present password')
                    if Account_detail[username.upper()]['password']==password:
                        new_password=input('Kya karna hai jaldi bata')
                        Account_detail[username.upper()]['password']=new_password
                        break
                    else:
                        print('Tu hi hai na sach bata')
            elif k==4:
                print(f'''

                Your Present balance is -->{Account_detail[username.upper()]['balance']}

                ''')
            elif k==5:
                 print(f'''
                Name : {Account_detail[username.upper()]['name']}
                Mobile no : {Account_detail[username.upper()]['Mobileno']}
                address : {Account_detail[username.upper()]['Address']}
                accounttype : {Account_detail[username.upper()]['account_type']}
                Your Present balance is -->{Account_detail[username.upper()]['balance']}

                    ''')
            elif k==6:
                break
        break
    elif n==4:
        break
    else:
        print('Invalid Input')
# Out:
#     Press 1 for Signup
#     Press 2 for Login
#     Press 3 for Forget Password
#     Press 4 for Exit
#     2
# Enter your usernamea101
# Enter Your PasswordSachin
# Login Successfully
#
#                 Press 1 for Credit
#                 Press 2 for Debit
#                 Press 3 for Change Password
#                 Press 4 for Check Balance
#                 Press 5 for Show Details
#                 Press 6 for Logout
#             4
#
#
#                 Your Present balance is -->200
#
#
#
#                 Press 1 for Credit
#                 Press 2 for Debit
#                 Press 3 for Change Password
#                 Press 4 for Check Balance
#                 Press 5 for Show Details
#                 Press 6 for Logout
#             5
#
#                 Name : Sachin
#                 Mobile no : 9511339055
#                 address : Jaipur
#                 accounttype : S
#                 Your Present balance is -->200
#
#
#
# ...

# %%
#Signup
print('*'*10,'Welcome to Besahara Bank🐫🐫','*'*10)
while True:

    n=int(input('''
       Press 1 for Create Acoount
       Press 2 for Exit
    '''))
    if n==1:
        print('Welcome to the Account Handling Department')
        print('We Would like to request you with some detail')
        name=input('Enter Your name')
        no=int(input('Enter your mobile no'))
        address=input('Enter your address')
        account_type=input('''
        Press "S" for Saving Account
        Press "C" for Current Account 
        ''')
        a=list(Account_detail.keys())[-1]
        account_no=a[0]+str(int(a[1:])+1)
        while True:
            password=input('Enter a Strong Password')
            b = "qwertyuiopasdfghjklzxcvbnm"
            d = {
            "cap" : b.upper(),
            "low" : b,
            "num" : '0123456789',
            "sc"  : '!@#$%^&*()-=+_<>?/.,;:' 
            }
            c,l,s,n = 0,0,0,0
            for i in password:
                if i in d['cap']:
                    c += 1
                elif i in d['low']:
                    l += 1
                elif i in d['sc']:
                    s += 1
                elif i in d['num']:
                    n += 1

            ls = []
            if c == 0:
                ls.append("Capital letters")
            if l == 0:
                ls.append("Small Letters")
            if s == 0:
                ls.append("Special Characters")
            if n == 0:
                ls.append("Numbers")

            if len(ls) == 0 and len(password) > 7:
                break
            else:
                print("Your password is Weak")
                if len(password) < 7:
                    print("Your password must have at least 8 characters")
                if ls != 0:
                    print(ls,"are missing in your password ")
        while True:
            balance=int(input('Enter Intial Balance To depoist must be greater than 2000'))
            if balance>=2000:
                break
            else:
                print('Deposited Balance is less than 2000')
        d[account_no]={'password'password,name.title(),no,address,balance,account_type.upper()]
        print(f'''
        Welcome {name}
        
                    Your Account no : {account_no}
                    Your Password   : {password}
                    ''')
        print('*'*10,'Aapka saath humara vikas🦏🦌🦌🦏','*'*10)
        break
# Out:
# ********** Welcome to Besahara Bank🐫🐫 **********
#
#        Press 1 for Create Acoount
#        Press 2 for Exit
#     1
# Welcome to the Account Handling Department
# We Would like to request you with some detail
# Enter Your namesachin
# Enter your mobile no9511339055
# Enter your addressjaipur
#
#         Press "S" for Saving Account
#         Press "C" for Current Account
#         s
# Enter a Strong PasswordSachin@123
# Enter Intial Balance To depoist must be greater than 20002001
#
#         Welcome sachin
#
#                     Your Account no : A102
#                     Your Password   : Sachin@123

# %%
#password Checker
password='sachin'

b = "qwertyuiopasdfghjklzxcvbnm"
d = {
        "cap" : b.upper(),
        "low" : b,
        "num" : '0123456789',
        "sc"  : '!@#$%^&*()-=+_<>?/.,;:' 
    }
c,l,s,n = 0,0,0,0
for i in password:
    if i in d['cap']:
        c += 1
    elif i in d['low']:
        l += 1
    elif i in d['sc']:
        s += 1
    elif i in d['num']:
        n += 1

    ls = []
    if c == 0:
         ls.append("Capital letters")
    if l == 0:
        ls.append("Small Letters")
    if s == 0:
        ls.append("Special Characters")
    if n == 0:
        ls.append("Numbers")

    if len(ls) == 0 and len(password) > 7:
        break
else:
    print("Your password is Weak")
    if len(password) < 7:
        print("Your password must have at least 8 characters")
    if ls != 0:
        print(ls,"are missing in your password ")
# Out:
# Your password is Weak
# Your password must have at least 8 characters
# ['Capital letters', 'Special Characters', 'Numbers'] are missing in your password

# %%
i=0
while True: 
    username=input('Enter your username')
    password=input('Enter Your Password')
    i+=1
    if username.upper() in list(Account_detail.keys()):
        if password ==Account_detail[username.upper()]:
            print('Login Successfully')
            break
        else:
            print('Wrong Password')
    else :
        print('No username Found')
    if i>=3:
        sys.exit('You have entered 3 wrong password in a row')
while True:
    k=int(input('''
        Press 1 for Credit 
        Press 2 for Debit
        Press 3 for Change Password 
        Press 4 for Check Balance
        Press 5 for Show Details
        Press 6 for Logout
    '''))
    if k==1:
        credit_amount=int(input('Enter Amount to Deposit'))
        Account_detail[username.upper()][balance]+=credit_amount
    elif k==2:
        debit_amount=int(input('Enter Amount to debit'))
        if debit_amount>Account_detail[username.upper()][balance]:
            print('Aukad se bahar😎😎')
        else:
            Account_detail[username.upper()][balance]-=debit_amount
            print(f'''
            
            Amount Debited-->{debit_amount}
            Present Balance-->{Account_detail[username.upper()][balance]}
            
            Kya karega itne paise ka 😏😏
            
            ''')
        if Account_detail[username.upper()][balance]<2000:
            print('Paisa kam hai tere paas 😆😅')
        
    elif k==3:
        while True:
            password=input('Enter your present password')
            if Account_detail[username.upper()][password]==password:
                new_password=input('Kya karna hai jaldi bata')
                Account_detail[username.upper()][password]=new_password
                break
            else:
                print('Tu hi hai na sach bata')
    elif k==4:
        print(f'''
        
        Your Present balance is -->{Account_detail[username.upper()][balance]}
        
        ''')
    elif k==5:
         print(f'''
        Name : {Account_detail[username.upper()][name]}
        Mobile no : {Account_detail[username.upper()][Mobileno]}
        address : {Account_detail[username.upper()][Address]}
        accounttype : {Account_detail[username.upper()][account_type]}
        Your Present balance is -->{Account_detail[username.upper()][balance]}
        
            ''')
    elif k==6:
        break
break
# Out:
# Enter your usernamea101
# Enter Your Passwordsa
# Wrong Password

# %%
username.upper()
# Out:
# 'A101'

# %%
while True :
    quit()
# Out:
# KeyboardInterrupt

# %%
import sys
i=0
while i<5:
    if i==3:
        sys.exit('You have entered 3 wrong password in a row')
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: You have entered 3 wrong password in a row
