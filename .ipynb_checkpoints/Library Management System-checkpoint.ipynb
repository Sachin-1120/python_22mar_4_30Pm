# %%
import sys
import datetime

# %%
book={
    'B101':{ 'title':'The Python','Author':'XYZ','Copies':10,'year':2007},
    'B102':{ 'title':'Data the Lake','Author':'XYZ','Copies':10,'year':2007},
    'B103':{ 'title':'The Beginning Story','Author':'XYZ','Copies':10,'year':2007},
    'B104':{ 'title':'The ','Author':'XYZ','Copies':10,'year':2007},
    'B105':{ 'title':'Data science','Author':'XYZ','Copies':10,'year':2007},
    'B106':{ 'title':'Data Analyst','Author':'XYZ','Copies':10,'year':2007},
    'B107':{ 'title':'Devops','Author':'XYZ','Copies':10,'year':2007},
    'B108':{ 'title':'linux Basics','Author':'XYZ','Copies':10,'year':2007},
    'B109':{ 'title':'ss1','Author':'XYZ','Copies':10,'year':2007},
    'B110':{ 'title':'ss2','Author':'XYZ','Copies':10,'year':2007},
    'B111':{ 'title':'ss3','Author':'XYZ','Copies':10,'year':2007},
    'B112':{ 'title':'ss4','Author':'XYZ','Copies':10,'year':2007},
    'B113':{ 'title':'ss5','Author':'XYZ','Copies':10,'year':2007},
    'B114':{ 'title':'ss6','Author':'XYZ','Copies':10,'year':2007},    
}
student={
    's101':{'name':'sachin','contact':7878012779,'Issued_book':{'name':'the Python','Book_id':'B101' ,'Date_of_issue':'2024-06-02'},
            'Fine':0
}

while True:
    print('Welcome to Vasul Library😀😀😀'.center(90,'*'))
    n=int(input('''
    Press 1 for Login
    Press 2 for Signup
    Press 3 for Forget Password
    Press 4 Exit
    '''))
    if n==1:
        login()
    elif n==2:
        signup()
    elif n==3:
        password()
    elif n==4:
        break
    else:
        print('Invalid  Input')
# Out:
#   Cell In[2], line 17
#     student={
#             ^
# SyntaxError: '{' was never closed

# %%
def fine(a):
    if student[a]['Issued_book']!=None:
        submission=datetime.date.today()
        issue=student[a]['Issued_book']['Date_of_issue']
        days=(submission-issue).days
        if days>7:
            return student[a]['Fine']+(days-7)*2
        else:
            return student[a]['Fine']
    else:
        return student[a]['Fine']

def login():
    while True:
        n=int(input('''
        Press 1 for Login
        Press 2 For Exit
    
        '''))
        if n==1:
            a=input('Enter Your Student_id')
            if a in student.keys():
                n=int(input('''
                Press 1 for Issue Book
                Press 2 to submit Book
                Press 3 to submit Fine
                Press 4 to check Fine
                Press 5 for check Personal Info
                Press 6 to Exit
                '''))
                if n==1:
                    book_id=input('Enter Book Id to Issue')
                    if book_id in book.keys():
                        if book[book_id]['copies']>=1:
                            print('Book Issued successfully')
                            print('Kindly Resubmit Book in 7 days otherwise fine will be imposed')
                            book[book_id]['copies']-=1

                            student[a]['Issued_book']['Book_id']=book_id
                            student[a]['Issued_book']['name']=book[book_id]['title']
                            student[a]['Issued_book']['Date_of_issue']=datetime.date.today
                            student[a]['Fine']=0
                elif n==2:
                    book_id=a['Issued_book']['Book_id']
                    print(f'{book_id} Submitted Successfully')
                    Fine=fine(a)
                    a['Fine']+=Fine
                    a['Issued_Book']=None
                    book[book_id]['copies']+=1
                elif n==3:
                    print(f'Total Fine Till Today -->{fine(a)}')
                    n=int(input('Enter Amount To Submit'))
                    student[a]['Fine']-=n
                    
                elif n==4:
                    print(f'Fine of studentId-{a} is {fine(a)}')
                elif n==5:
                    print(f'''
                    Hello {student[a]["name"]}
                    
                        Your Contact Detail is :{student[a]['contact']}
                        Your student Id is     : {a}
                    ''')
                elif n==6:
                    sys.exit('thanks For the Service')   
                
            else:
                print('No Such Student Found')
        elif n==2:
            sys.exit('User Requested to exit')
        else:
            print('Invalid Input')

# %%
book={
    'B101':{ 'title':'The Python','Author':'XYZ','Copies':10,'year':2007},
    'B102':{ 'title':'Data the Lake','Author':'XYZ','Copies':10,'year':2007},
    'B103':{ 'title':'The Beginning Story','Author':'XYZ','Copies':10,'year':2007},
    'B104':{ 'title':'The ','Author':'XYZ','Copies':10,'year':2007},
    'B105':{ 'title':'Data science','Author':'XYZ','Copies':10,'year':2007},
    'B106':{ 'title':'Data Analyst','Author':'XYZ','Copies':10,'year':2007},
    'B107':{ 'title':'Devops','Author':'XYZ','Copies':10,'year':2007},
    'B108':{ 'title':'linux Basics','Author':'XYZ','Copies':10,'year':2007},
    'B109':{ 'title':'ss1','Author':'XYZ','Copies':10,'year':2007},
    'B110':{ 'title':'ss2','Author':'XYZ','Copies':10,'year':2007},
    'B111':{ 'title':'ss3','Author':'XYZ','Copies':10,'year':2007},
    'B112':{ 'title':'ss4','Author':'XYZ','Copies':10,'year':2007},
    'B113':{ 'title':'ss5','Author':'XYZ','Copies':10,'year':2007},
    'B114':{ 'title':'ss6','Author':'XYZ','Copies':10,'year':2007},    
}
student={
    's101':{'name':'sachin','contact':7878012779,'Issued_book':{'name':'the Python','Book_id':'B101' ,'Date_of_issue':datetime.date(2024,4,2)},
            'Fine':0
}
}

while True:
    print('Welcome to Vasul Library😀😀😀'.center(90,'*'))
    n=int(input('''
    Press 1 for Login
    Press 2 for Signup
    Press 3 for Forget Password
    Press 4 Exit
    '''))
    if n==1:
        login()
    elif n==2:
        signup()
    elif n==3:
        password()
    elif n==4:
        break
    else:
        print('Invalid  Input')
# Out:
# *******************************Welcome to Vasul Library😀😀😀********************************
#
#     Press 1 for Login
#     Press 2 for Signup
#     Press 3 for Forget Password
#     Press 4 Exit
#     4

# %%
Admin_detail={'A101':'Grras'}
def Admin():
    while True:
        n=int(input('''
        Press 1 for Login
        Press 2 for Exit
        '''))
        if n==1:
            Admin_login()
        elif n==2:
            return 0
        else:
            print('Invalid Input')
def Admin_login():
    id_Admin=input('Enter your id')
    id_Admin=id_Admin.upper()
    password=input('Enter Password')
    if id_Admin.upper() in Admin_detail.keys():
        if password==Admin_detail[id_Admin]:
            print('Login Successfully')
            n=int(input('''
                press 1 for Student Detail
                Press 2 for Books Detail
                Press 3 for Total fine
                Press 4 for Exit
            '''))
            if n==1:
                print('-'*40)
                print(f'|{"Name":<10} |{"Student Id":5} | {"Contact":>10}|')
                print('-'*40)
                for i in student.keys():
                        print(f'|{student[i]["name"]:<10} |{i:5} | {student[i]["contact"]:>10}|')
                        print('-'*40)
            elif n==2:
                pass
            elif n==3:
                print('-'*40)
                print(f'|{"Name":<10} |{"Student Id":5} | {"Total Fine":>10}|')
                print('-'*40)
                for i in student.keys():
                        print(f'|{student[i]["name"]:<10} |{i:5} | {fine(i):>10}|')
                        print('-'*40)                
            
        else:
            print('Incorrect Password')
            sys.exit(0)
    else:
        print('Invalid Username')
        sys.exit(0)

# %%
Admin()
# Out:
#         Press 1 for Login
#         Press 2 for Exit
#         1
# Enter your ida101
# Enter PasswordGrras
# Login Successfully
#
#                 press 1 for Student Detail
#                 Press 2 for Books Detail
#                 Press 3 for Total fine
#                 Press 4 for Exit
#             3
# ----------------------------------------
# |Name       |Student Id | Total Fine|
# ----------------------------------------
# |sachin     |s101  |        112|
# ----------------------------------------
#
#         Press 1 for Login
#         Press 2 for Exit
#         2
# 0
